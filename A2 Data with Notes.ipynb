# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv('lex.csv')

# Display the first few rows of the dataframe to understand its structure
data.head()
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1       Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
# 2      Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4          UAE  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  ...
#
#    2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 0  75.9  76.1  76.2  76.4  76.5  76.7  76.8  77.0  77.1  77.3
# 1  75.8  75.9  76.0  76.1  76.3  76.4  76.5  76.7  76.8  76.9
# 2  88.9  89.0  89.2  89.3  89.4  89.5  89.6  89.7  89.8  90.0
# 3  91.0  91.1  91.3  91.4  91.5  91.6  91.7  91.8  91.9  92.0
# 4  83.7  83.8  83.9  84.0  84.1  84.2  84.3  84.5  84.6  84.7
#
# [5 rows x 302 columns]

# %%
import pandas as pd

# Load the CSV file and create the dataframe 'life'
file_path = 'lex.csv'
life = pd.read_csv(file_path)

# Display the first few rows of the dataframe 'life'
life.head()
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1       Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
# 2      Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4          UAE  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  ...
#
#    2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 0  75.9  76.1  76.2  76.4  76.5  76.7  76.8  77.0  77.1  77.3
# 1  75.8  75.9  76.0  76.1  76.3  76.4  76.5  76.7  76.8  76.9
# 2  88.9  89.0  89.2  89.3  89.4  89.5  89.6  89.7  89.8  90.0
# 3  91.0  91.1  91.3  91.4  91.5  91.6  91.7  91.8  91.9  92.0
# 4  83.7  83.8  83.9  84.0  84.1  84.2  84.3  84.5  84.6  84.7
#
# [5 rows x 302 columns]

# %%
# Melt the dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year column to numeric
life_long['year'] = pd.to_numeric(life_long['year'])

# Display the first few rows of the transformed dataframe
life_long.head()
# Out:
#        country  year  life_expectancy
# 0  Afghanistan  1800             28.2
# 1       Angola  1800             27.0
# 2      Albania  1800             35.4
# 3      Andorra  1800              NaN
# 4          UAE  1800             30.7

# %%
# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Display the first few rows to verify the changes
life_long.head()
# Out:
#        country  year  life_expectancy
# 0  Afghanistan  1800             28.2
# 1       Angola  1800             27.0
# 2      Albania  1800             35.4
# 3      Andorra  1800              NaN
# 4          UAE  1800             30.7

# %%
import pandas as pd

# Load the CSV file containing life expectancy data
file_path = 'lex.csv'
life = pd.read_csv(file_path)

# Melt the dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Load the CSV file containing country-region mappings
region_file_path = 'Country Region.csv'
country_region = pd.read_csv(region_file_path)

# Merge the life_long dataframe with the country_region dataframe
life = life_long.merge(country_region, on='country', how='left')

# Display the first few rows of the updated dataframe to verify the merge
life.head()
# Out:
#        country  year  life_expectancy  region
# 0  Afghanistan  1800             28.2    Asia
# 1       Angola  1800             27.0  Africa
# 2      Albania  1800             35.4  Europe
# 3      Andorra  1800              NaN  Europe
# 4          UAE  1800             30.7     NaN

# %%
# Identify countries that don't have a valid region
countries_without_region = life[life['region'].isna()]['country'].unique()

# Display the countries without a valid region
countries_without_region
# Out:
# array(['UAE', "Cote d'Ivoire", 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Micronesia, Fed. Sts.', 'UK', 'Hong Kong, China',
#        'North Macedonia', 'Eswatini'], dtype=object)

# %%
import pandas as pd

# Load the CSV file containing life expectancy data
file_path = 'lex.csv'
life = pd.read_csv(file_path)

# Melt the dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Load the CSV file containing country-region mappings
region_file_path = 'Country Region.csv'
country_region = pd.read_csv(region_file_path)

# Merge the life_long dataframe with the country_region dataframe
life = life_long.merge(country_region, on='country', how='left')

# Identify countries that don't have a valid region
countries_without_region = life[life['region'].isna()]['country'].unique()

# Drop the countries without a valid region
life = life[~life['country'].isin(countries_without_region)]

# Display the first few rows of the updated dataframe to verify the changes
life.head()
# Out:
#        country  year  life_expectancy    region
# 0  Afghanistan  1800             28.2      Asia
# 1       Angola  1800             27.0    Africa
# 2      Albania  1800             35.4    Europe
# 3      Andorra  1800              NaN    Europe
# 5    Argentina  1800             33.2  Americas

# %%
import pandas as pd

# Load the CSV files
life_file_path = 'lex.csv'
diff_refg_origin_path = 'diff_refg_origin.csv'
pop_path = 'pop.csv'

life = pd.read_csv(life_file_path)
diff_refg_origin = pd.read_csv(diff_refg_origin_path)
pop = pd.read_csv(pop_path)

# Melt the life dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Load the country-region mappings
region_file_path = 'Country Region.csv'
country_region = pd.read_csv(region_file_path)

# Merge the life_long dataframe with the country_region dataframe
life_long = life_long.merge(country_region, on='country', how='left')

# Merge the life_long dataframe with diff_refg_origin and pop dataframes
diff_refg_origin_long = diff_refg_origin.melt(id_vars=['country'], var_name='year', value_name='refugee_origin')
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Convert the year columns to numeric
diff_refg_origin_long['year'] = pd.to_numeric(diff_refg_origin_long['year'])
pop_long['year'] = pd.to_numeric(pop_long['year'])

# Merge all dataframes on country and year
merged_df = life_long.merge(diff_refg_origin_long, on=['country', 'year'], how='inner')
merged_df = merged_df.merge(pop_long, on=['country', 'year'], how='inner')

# Drop rows with any missing data
my_analysis_df = merged_df.dropna()

# Display the first few rows of the resulting dataframe
my_analysis_df.head()
# Out:
#         country  year  life_expectancy    region refugee_origin population
# 8     Australia  1951             69.2      Asia            25k      8.42M
# 9       Austria  1951             65.5    Europe             75      6.93M
# 12      Belgium  1951             67.1    Europe          16.2k      8.66M
# 29       Canada  1951             68.8  Americas           160k      14.1M
# 30  Switzerland  1951             69.0    Europe             81      4.75M

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the dataframe for the USA
usa_data = my_analysis_df[my_analysis_df['country'] == 'USA'].copy()

# Ensure the refugee_origin and population columns are numeric
usa_data.loc[:, 'refugee_origin'] = pd.to_numeric(usa_data['refugee_origin'], errors='coerce')
usa_data.loc[:, 'population'] = pd.to_numeric(usa_data['population'], errors='coerce')

# Drop rows with any missing or invalid data
usa_data = usa_data.dropna(subset=['life_expectancy', 'refugee_origin', 'population'])

# Plot time series for life expectancy
plt.figure(figsize=(10, 5))
plt.plot(usa_data['year'], usa_data['life_expectancy'], marker='o')
plt.title('Life Expectancy in the USA')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# Plot time series for refugee origin
plt.figure(figsize=(10, 5))
plt.plot(usa_data['year'], usa_data['refugee_origin'], marker='o', color='orange')
plt.title('Refugee Origin in the USA')
plt.xlabel('Year')
plt.ylabel('Refugee Origin')
plt.grid(True)
plt.show()

# Plot time series for population
plt.figure(figsize=(10, 5))
plt.plot(usa_data['year'], usa_data['population'], marker='o', color='green')
plt.title('Population in the USA')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the dataframe for the year 2010
data_2010 = my_analysis_df[my_analysis_df['year'] == 2010]

# Identify the 20 countries with the lowest life expectancy in 2010
lowest_life_expectancy_2010 = data_2010.nsmallest(20, 'life_expectancy')

# Add the USA to this list if it's not already included
if 'USA' not in lowest_life_expectancy_2010['country'].values:
    usa_2010 = data_2010[data_2010['country'] == 'USA']
    lowest_life_expectancy_2010 = pd.concat([lowest_life_expectancy_2010, usa_2010])

# Sort the data by life expectancy in ascending order for plotting
lowest_life_expectancy_2010 = lowest_life_expectancy_2010.sort_values(by='life_expectancy', ascending=True)

# Plot the data
plt.figure(figsize=(12, 8))
plt.barh(lowest_life_expectancy_2010['country'], lowest_life_expectancy_2010['life_expectancy'], color='skyblue')
plt.xlabel('Life Expectancy')
plt.ylabel('Country')
plt.title('20 Countries with the Lowest Life Expectancy in 2010 (Including USA)')
plt.grid(axis='x')

# Invert y-axis to have the highest values on top
plt.gca().invert_yaxis()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the dataframe for the year 2010
data_2010 = my_analysis_df[my_analysis_df['year'] == 2010].copy()

# Ensure the refugee_origin column is numeric
data_2010['refugee_origin'] = pd.to_numeric(data_2010['refugee_origin'], errors='coerce')

# Identify the 25 countries with the highest refugee counts in 2010
highest_refugee_2010 = data_2010.nlargest(25, 'refugee_origin')

# Sort the data by refugee counts in descending order for plotting
highest_refugee_2010 = highest_refugee_2010.sort_values(by='refugee_origin', ascending=False)

# Plot the data
plt.figure(figsize=(12, 8))
plt.barh(highest_refugee_2010['country'], highest_refugee_2010['refugee_origin'], color='skyblue')
plt.xlabel('Refugee Origin')
plt.ylabel('Country')
plt.title('25 Countries with the Highest Refugee Counts in 2010')
plt.grid(axis='x')

# Invert y-axis to have the highest values on top
plt.gca().invert_yaxis()
plt.show()

# %%
import pandas as pd

# Re-import necessary data and perform the merge operations to recreate my_analysis_df

# Load the CSV files
life_file_path = 'lex.csv'
diff_refg_origin_path = 'diff_refg_origin.csv'
pop_path = 'pop.csv'

life = pd.read_csv(life_file_path)
diff_refg_origin = pd.read_csv(diff_refg_origin_path)
pop = pd.read_csv(pop_path)

# Melt the life dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Load the country-region mappings
region_file_path = 'Country Region.csv'
country_region = pd.read_csv(region_file_path)

# Merge the life_long dataframe with the country_region dataframe
life_long = life_long.merge(country_region, on='country', how='left')

# Merge the life_long dataframe with diff_refg_origin and pop dataframes
diff_refg_origin_long = diff_refg_origin.melt(id_vars=['country'], var_name='year', value_name='refugee_origin')
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Convert the year columns to numeric
diff_refg_origin_long['year'] = pd.to_numeric(diff_refg_origin_long['year'])
pop_long['year'] = pd.to_numeric(pop_long['year'])

# Merge all dataframes on country and year
merged_df = life_long.merge(diff_refg_origin_long, on=['country', 'year'], how='inner')
merged_df = merged_df.merge(pop_long, on=['country', 'year'], how='inner')

# Drop rows with any missing data
my_analysis_df = merged_df.dropna()

# Ensure that the relevant columns are numeric
data_2010 = my_analysis_df[my_analysis_df['year'] == 2010].copy()
data_2010['life_expectancy'] = pd.to_numeric(data_2010['life_expectancy'], errors='coerce')
data_2010['population'] = pd.to_numeric(data_2010['population'], errors='coerce')
data_2010['refugee_origin'] = pd.to_numeric(data_2010['refugee_origin'], errors='coerce')

# Identify the top 10 countries with the highest life expectancy in 2010
highest_life_expectancy_2010 = data_2010.nlargest(10, 'life_expectancy')[['country', 'life_expectancy']]

# Identify the top 10 countries with the highest population in 2010
highest_population_2010 = data_2010.nlargest(10, 'population')[['country', 'population']]

# Identify the top 10 countries with the highest refugee counts in 2010
highest_refugee_2010 = data_2010.nlargest(10, 'refugee_origin')[['country', 'refugee_origin']]

# Display the results
print("Top 10 Countries with the Highest Life Expectancy in 2010:")
print(highest_life_expectancy_2010)

print("\nTop 10 Countries with the Highest Population in 2010:")
print(highest_population_2010)

print("\nTop 10 Countries with the Highest Refugee Counts in 2010:")
print(highest_refugee_2010)
# Out:
# Top 10 Countries with the Highest Life Expectancy in 2010:
#              country  life_expectancy
# 11592          Japan             83.3
# 11535    Switzerland             82.8
# 11658      Singapore             82.8
# 11587        Iceland             82.6
# 11513      Australia             82.1
# 11558          Spain             82.1
# 11589          Italy             82.1
# 11606  Liechtenstein             82.0
# 11588         Israel             81.9
# 11670         Sweden             81.9
#
# Top 10 Countries with the Highest Population in 2010:
#                    country  population
# 11505          Afghanistan         NaN
# 11506               Angola         NaN
# 11507              Albania         NaN
# 11508              Andorra         NaN
# 11510            Argentina         NaN
# 11511              Armenia         NaN
# 11512  Antigua and Barbuda         NaN
# 11513            Australia         NaN
# 11514              Austria         NaN
# ...

# %%
import pandas as pd

# Load the CSV file containing population data
pop_path = 'pop.csv'
pop = pd.read_csv(pop_path)

# Melt the dataframe to convert year columns into a variable
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Replace 'M' and 'k' with their numerical equivalents and convert to numeric
pop_long['population'] = pd.to_numeric(pop_long['population'].str.replace('M', 'e6').str.replace('k', 'e3'), errors='coerce')

# Display the first few rows to verify the changes
print(pop_long.head())
# Out:
#        country  year  population
# 0  Afghanistan  1800   3280000.0
# 1       Angola  1800   1570000.0
# 2      Albania  1800    400000.0
# 3      Andorra  1800      2650.0
# 4          UAE  1800     40200.0

# %%
import pandas as pd

# Load the existing my_analysis_df if it's not already loaded
# my_analysis_df = ...

# Load the CSV file containing population data
pop_file_path = 'pop.csv'
pop = pd.read_csv(pop_file_path)

# Melt the pop dataframe to convert year columns into a variable
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Convert the year column to numeric
pop_long['year'] = pd.to_numeric(pop_long['year'])

# Replace 'M' and 'k' with their numerical equivalents and convert to numeric
pop_long['population'] = pd.to_numeric(pop_long['population'].str.replace('M', 'e6').str.replace('k', 'e3'), errors='coerce')

# Ensure columns in my_analysis_df are properly named and formatted
my_analysis_df['year'] = pd.to_numeric(my_analysis_df['year'], errors='coerce')

# Merge the my_analysis_df dataframe with the pop_long dataframe
my_analysis_df = my_analysis_df.merge(pop_long, on=['country', 'year'], how='left')

# Verify the merge and column names
print(my_analysis_df.head())
print(my_analysis_df.columns)

# Filter the dataframe for the year 2010
data_2010 = my_analysis_df[my_analysis_df['year'] == 2010].copy()

# Ensure the relevant columns are numeric
data_2010['life_expectancy'] = pd.to_numeric(data_2010['life_expectancy'], errors='coerce')
data_2010['population'] = pd.to_numeric(data_2010['population'], errors='coerce')
data_2010['refugee_origin'] = pd.to_numeric(data_2010['refugee_origin'], errors='coerce')

# Drop rows with NaN values in the relevant columns
data_2010_clean = data_2010.dropna(subset=['life_expectancy', 'population', 'refugee_origin'])

# Identify the top 10 countries with the highest life expectancy in 2010
highest_life_expectancy_2010 = data_2010_clean.nlargest(10, 'life_expectancy')[['country', 'life_expectancy']]

# Identify the top 10 countries with the highest population in 2010
highest_population_2010 = data_2010_clean.nlargest(10, 'population')[['country', 'population']]

# Identify the top 10 countries with the highest refugee counts in 2010
highest_refugee_2010 = data_2010_clean.nlargest(10, 'refugee_origin')[['country', 'refugee_origin']]

# Display the results
print("Top 10 Countries with the Highest Life Expectancy in 2010:")
print(highest_life_expectancy_2010)

print("\nTop 10 Countries with the Highest Population in 2010:")
print(highest_population_2010)

print("\nTop 10 Countries with the Highest Refugee Counts in 2010:")
print(highest_refugee_2010)
# Out:
#        country  year  life_expectancy    region refugee_origin population_x  \
# 0    Australia  1951             69.2      Asia            25k        8.42M
# 1      Austria  1951             65.5    Europe             75        6.93M
# 2      Belgium  1951             67.1    Europe          16.2k        8.66M
# 3       Canada  1951             68.8  Americas           160k        14.1M
# 4  Switzerland  1951             69.0    Europe             81        4.75M
#
#    population_y
# 0     8420000.0
# 1     6930000.0
# 2     8660000.0
# 3    14100000.0
# 4     4750000.0
# Index(['country', 'year', 'life_expectancy', 'region', 'refugee_origin',
#        'population_x', 'population_y'],
#       dtype='object')
# C:\Users\pchhay\AppData\Local\Temp\ipykernel_18400\2948255933.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing population data
pop_file_path = 'pop.csv'
pop = pd.read_csv(pop_file_path)

# Melt the pop dataframe to convert year columns into a variable
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Convert the year column to numeric
pop_long['year'] = pd.to_numeric(pop_long['year'])

# Replace 'M' and 'k' with their numerical equivalents and convert to numeric
pop_long['population'] = pd.to_numeric(pop_long['population'].str.replace('M', 'e6').str.replace('k', 'e3'), errors='coerce')

# Assuming my_analysis_df is already loaded and contains the merged data from previous steps
# Ensure columns in my_analysis_df are properly named and formatted
my_analysis_df['year'] = pd.to_numeric(my_analysis_df['year'], errors='coerce')

# Merge the my_analysis_df dataframe with the pop_long dataframe, using suffixes to avoid conflicts
my_analysis_df = my_analysis_df.merge(pop_long, on=['country', 'year'], how='left', suffixes=('', '_pop'))

# Filter the dataframe for the year 2010
data_2010 = my_analysis_df[my_analysis_df['year'] == 2010].copy()

# Ensure the relevant columns are numeric
data_2010['life_expectancy'] = pd.to_numeric(data_2010['life_expectancy'], errors='coerce')
data_2010['population'] = pd.to_numeric(data_2010['population'], errors='coerce')
data_2010['refugee_origin'] = pd.to_numeric(data_2010['refugee_origin'], errors='coerce')

# Drop rows with NaN values in the relevant columns
data_2010_clean = data_2010.dropna(subset=['life_expectancy', 'population', 'refugee_origin'])

# Identify the top 10 countries with the highest life expectancy in 2010
highest_life_expectancy_2010 = data_2010_clean.nlargest(10, 'life_expectancy')[['country', 'life_expectancy']]

# Identify the top 10 countries with the highest population in 2010
highest_population_2010 = data_2010_clean.nlargest(10, 'population')[['country', 'population']]

# Identify the top 10 countries with the highest refugee counts in 2010
highest_refugee_2010 = data_2010_clean.nlargest(10, 'refugee_origin')[['country', 'refugee_origin']]

# Plot the data
plt.figure(figsize=(12, 8))
plt.barh(highest_life_expectancy_2010['country'], highest_life_expectancy_2010['life_expectancy'], color='skyblue')
plt.xlabel('Life Expectancy')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Highest Life Expectancy in 2010')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

plt.figure(figsize=(12, 8))
plt.barh(highest_population_2010['country'], highest_population_2010['population'], color='green')
plt.xlabel('Population')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Highest Population in 2010')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

plt.figure(figsize=(12, 8))
plt.barh(highest_refugee_2010['country'], highest_refugee_2010['refugee_origin'], color='orange')
plt.xlabel('Refugee Origin')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Highest Refugee Counts in 2010')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing population data
pop_file_path = 'pop.csv'
pop = pd.read_csv(pop_file_path)

# Melt the pop dataframe to convert year columns into a variable
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Convert the year column to numeric
pop_long['year'] = pd.to_numeric(pop_long['year'])

# Replace 'M' and 'k' with their numerical equivalents and convert to numeric
pop_long['population'] = pd.to_numeric(pop_long['population'].str.replace('M', 'e6').str.replace('k', 'e3'), errors='coerce')

# Assuming my_analysis_df is already loaded and contains the merged data from previous steps
# Ensure columns in my_analysis_df are properly named and formatted
my_analysis_df['year'] = pd.to_numeric(my_analysis_df['year'], errors='coerce')

# Merge the my_analysis_df dataframe with the pop_long dataframe, using suffixes to avoid conflicts
my_analysis_df = my_analysis_df.merge(pop_long, on=['country', 'year'], how='left', suffixes=('', '_pop'))

# Filter the dataframe for the year 2010
data_2010 = my_analysis_df[my_analysis_df['year'] == 2010].copy()

# Ensure the relevant columns are numeric
data_2010['life_expectancy'] = pd.to_numeric(data_2010['life_expectancy'], errors='coerce')
data_2010['population'] = pd.to_numeric(data_2010['population'], errors='coerce')
data_2010['refugee_origin'] = pd.to_numeric(data_2010['refugee_origin'], errors='coerce')

# Drop rows with NaN values in the relevant columns
data_2010_clean = data_2010.dropna(subset=['life_expectancy', 'population', 'refugee_origin'])

# Identify the top 10 countries with the lowest life expectancy in 2010
lowest_life_expectancy_2010 = data_2010_clean.nsmallest(10, 'life_expectancy')[['country', 'life_expectancy']]

# Identify the top 10 countries with the lowest population in 2010
lowest_population_2010 = data_2010_clean.nsmallest(10, 'population')[['country', 'population']]

# Identify the top 10 countries with the lowest refugee counts in 2010
lowest_refugee_2010 = data_2010_clean.nsmallest(10, 'refugee_origin')[['country', 'refugee_origin']]

# Plot the data
plt.figure(figsize=(12, 8))
plt.barh(lowest_life_expectancy_2010['country'], lowest_life_expectancy_2010['life_expectancy'], color='skyblue')
plt.xlabel('Life Expectancy')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Lowest Life Expectancy in 2010')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

plt.figure(figsize=(12, 8))
plt.barh(lowest_population_2010['country'], lowest_population_2010['population'], color='green')
plt.xlabel('Population')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Lowest Population in 2010')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

plt.figure(figsize=(12, 8))
plt.barh(lowest_refugee_2010['country'], lowest_refugee_2010['refugee_origin'], color='orange')
plt.xlabel('Refugee Origin')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Lowest Refugee Counts in 2010')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing life expectancy data
life_file_path = 'lex.csv'
life = pd.read_csv(life_file_path)

# Melt the life dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Aggregate the data to find the average life expectancy per year
life_trend = life_long.groupby('year')['life_expectancy'].mean().reset_index()

# Plot the trend of life expectancy data
plt.figure(figsize=(12, 8))
plt.plot(life_trend['year'], life_trend['life_expectancy'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Average Life Expectancy')
plt.title('Trend of Average Life Expectancy Over Time')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV files containing life expectancy data and region data
life_file_path = 'lex.csv'
region_file_path = 'Country Region.csv'

life = pd.read_csv(life_file_path)
country_region = pd.read_csv(region_file_path)

# Melt the life dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Merge the life_long dataframe with the country_region dataframe
life_with_region = life_long.merge(country_region, on='country', how='left')

# Aggregate the data to find the average life expectancy per region
region_life_expectancy = life_with_region.groupby('region')['life_expectancy'].mean().reset_index()

# Plot the average life expectancy for each region
plt.figure(figsize=(12, 8))
plt.barh(region_life_expectancy['region'], region_life_expectancy['life_expectancy'], color='skyblue')
plt.xlabel('Average Life Expectancy')
plt.ylabel('Region')
plt.title('Average Life Expectancy by Region')
plt.grid(axis='x')
plt.gca().invert_yaxis()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing life expectancy data
life_file_path = 'lex.csv'
life = pd.read_csv(life_file_path)

# Melt the life dataframe to convert year columns into a variable
life_long = life.melt(id_vars=['country'], var_name='year', value_name='life_expectancy')

# Convert the year and life_expectancy columns to numeric
life_long['year'] = pd.to_numeric(life_long['year'])
life_long['life_expectancy'] = pd.to_numeric(life_long['life_expectancy'])

# Select specific years for comparison
selected_years = [1900, 1950, 2000, 2010, 2020]

# Filter the dataframe for the selected years
life_selected_years = life_long[life_long['year'].isin(selected_years)]

# Aggregate the data to find the average life expectancy per year
life_expectancy_trend = life_selected_years.groupby('year')['life_expectancy'].mean().reset_index()

# Plot the average life expectancy for the selected years
plt.figure(figsize=(12, 8))
plt.plot(life_expectancy_trend['year'], life_expectancy_trend['life_expectancy'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Average Life Expectancy')
plt.title('Comparison of Average Life Expectancy Across Selected Years')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing population data
pop_file_path = 'pop.csv'
pop = pd.read_csv(pop_file_path)

# Melt the pop dataframe to convert year columns into a variable
pop_long = pop.melt(id_vars=['country'], var_name='year', value_name='population')

# Convert the year column to numeric
pop_long['year'] = pd.to_numeric(pop_long['year'])

# Replace 'M' and 'k' with their numerical equivalents and convert to numeric
pop_long['population'] = pd.to_numeric(pop_long['population'].str.replace('M', 'e6').str.replace('k', 'e3'), errors='coerce')

# Select specific years for comparison
selected_years = [1900, 1950, 2000, 2010, 2020]

# Filter the dataframe for the selected years
pop_selected_years = pop_long[pop_long['year'].isin(selected_years)]

# Aggregate the data to find the average population per year
population_trend = pop_selected_years.groupby('year')['population'].mean().reset_index()

# Plot the average population for the selected years
plt.figure(figsize=(12, 8))
plt.plot(population_trend['year'], population_trend['population'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Average Population')
plt.title('Comparison of Average Population Across Selected Years')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing refugee data
refugee_file_path = 'diff_refg_origin.csv'
refugee = pd.read_csv(refugee_file_path)

# Melt the refugee dataframe to convert year columns into a variable
refugee_long = refugee.melt(id_vars=['country'], var_name='year', value_name='refugee_origin')

# Convert the year column to numeric
refugee_long['year'] = pd.to_numeric(refugee_long['year'])

# Replace 'M' and 'k' with their numerical equivalents and convert to numeric
refugee_long['refugee_origin'] = pd.to_numeric(refugee_long['refugee_origin'].str.replace('M', 'e6').str.replace('k', 'e3'), errors='coerce')

# Select specific years for comparison
selected_years = [1900, 1950, 2000, 2010, 2020]

# Filter the dataframe for the selected years
refugee_selected_years = refugee_long[refugee_long['year'].isin(selected_years)]

# Aggregate the data to find the average refugee counts per year
refugee_trend = refugee_selected_years.groupby('year')['refugee_origin'].mean().reset_index()

# Plot the average refugee counts for the selected years
plt.figure(figsize=(12, 8))
plt.plot(refugee_trend['year'], refugee_trend['refugee_origin'], marker='o', linestyle='-', color='b')
plt.xlabel('Year')
plt.ylabel('Average Refugee Origin')
plt.title('Comparison of Average Refugee Origin Across Selected Years')
plt.grid(True)
plt.show()
